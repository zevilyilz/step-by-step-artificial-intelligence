# %%
pip install stylecloud
# Out:
# Collecting stylecloud
#   Downloading stylecloud-0.5.2.tar.gz (262 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 262.1/262.1 kB 12.3 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: wordcloud in /usr/local/lib/python3.10/dist-packages (from stylecloud) (1.9.3)
# Collecting icon-font-to-png (from stylecloud)
#   Downloading icon_font_to_png-0.4.1-py2.py3-none-any.whl.metadata (6.7 kB)
# Collecting palettable (from stylecloud)
#   Downloading palettable-3.3.3-py2.py3-none-any.whl.metadata (3.3 kB)
# Collecting fire (from stylecloud)
#   Downloading fire-0.6.0.tar.gz (88 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.4/88.4 kB 4.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from stylecloud) (3.7.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from fire->stylecloud) (1.16.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.10/dist-packages (from fire->stylecloud) (2.4.0)
# Requirement already satisfied: Pillow>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from icon-font-to-png->stylecloud) (9.4.0)
# Requirement already satisfied: requests>=2.12.5 in /usr/local/lib/python3.10/dist-packages (from icon-font-to-png->stylecloud) (2.32.3)
# Collecting tinycss>=0.4 (from icon-font-to-png->stylecloud)
#   Downloading tinycss-0.4.tar.gz (87 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 87.8/87.8 kB 5.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (1.4.7)
# Requirement already satisfied: numpy>=1.20 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->stylecloud) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (3.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.12.5->icon-font-to-png->stylecloud) (2024.8.30)
# Downloading icon_font_to_png-0.4.1-py2.py3-none-any.whl (161 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 161.4/161.4 kB 6.0 MB/s eta 0:00:00
# Downloading palettable-3.3.3-py2.py3-none-any.whl (332 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 332.3/332.3 kB 14.4 MB/s eta 0:00:00
# Building wheels for collected packages: stylecloud, fire, tinycss
#   Building wheel for stylecloud (setup.py) ... done
#   Created wheel for stylecloud: filename=stylecloud-0.5.2-py3-none-any.whl size=259491 sha256=1c4793b32c8481946495e747c69a893a460fffbcedee482f6dde715930069a4b
#   Stored in directory: /root/.cache/pip/wheels/aa/c8/27/9374f4fc7133015d902b5e2c75ad951edd57eb1ae948495915
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.6.0-py2.py3-none-any.whl size=117030 sha256=8a21cbbc433edeb2b125e3a5fd6ede750218d55a5f40c55679b880f800e880d0
#   Stored in directory: /root/.cache/pip/wheels/d6/6d/5d/5b73fa0f46d01a793713f8859201361e9e581ced8c75e5c6a3
#   Building wheel for tinycss (setup.py) ... done
#   Created wheel for tinycss: filename=tinycss-0.4-cp310-cp310-linux_x86_64.whl size=307594 sha256=eee0cd3ee0102162c2d210794968044baa8db7503cb1aea2b80cd182c0d4e651
#   Stored in directory: /root/.cache/pip/wheels/39/52/4c/ca7bc9c8bb0fc4789d806bf78cac9d230efb3d3d8082e247c6
# Successfully built stylecloud fire tinycss
# Installing collected packages: tinycss, palettable, fire, icon-font-to-png, stylecloud
# Successfully installed fire-0.6.0 icon-font-to-png-0.4.1 palettable-3.3.3 stylecloud-0.5.2 tinycss-0.4

# %%
import stylecloud as sc
import matplotlib.pyplot as plt

# %%
sc.gen_stylecloud(file_path="challenge.txt",output_name="ch.png" )

# %%
from IPython.display import Image
Image("ch.png")

# %%
sc.gen_stylecloud(file_path="challenge.txt",icon_name= "fas fa-car" ,output_name="ch2.png" )

# %%
from IPython.display import Image
Image("ch2.png")
